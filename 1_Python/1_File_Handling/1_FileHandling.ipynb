# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sumit\\OneDrive\\Desktop\\Data Science\\1_Python\\1_File_Handling'

# %%
os.listdir(r'c:\\Users\\sumit\\OneDrive\\Desktop\\Data Science')
# Out:
# ['.git', '.gitignore', '1_Python', 'readme.md', 'requirement.txt', 'venv']

# %%
os.path.join( os.getcwd() , 'text.txt' , 'abc')
# Out:
# 'c:\\Users\\sumit\\OneDrive\\Desktop\\Data Science\\1_Python\\1_File_Handling\\text.txt\\abc'

# %%
# open file

with open('test.txt' , 'r') as file:
    print(file.readlines())
# Out:
# ['Hello This is first line huhh\n', 'And this is second line uumm']

# %%
full_path = os.path.join(os.getcwd() , 'test.txt')
print(full_path)

file2 = open(full_path , 'r')
print(file2.read())
file2.close()
# Out:
# c:\Users\sumit\OneDrive\Desktop\Data Science\1_Python\1_File_Handling\test.txt
# Hello This is first line huhh
# And this is second line uumm

# %%
with open('./test.txt' , 'w') as f:
    lines = ["heyyy.. so it is 2nd line\n" , "and this is my 3rd line\n"]
    f.write("so it's first line ayooo\n")
    f.writelines(lines)

# %%
with open('./test.txt' , 'a') as f:
    f.write("hell yeahh i'm appending my 6th line\n")

# %%
with open("./dummy.txt" , 'a+') as f:
    f.write("Hello it is first line\n")
    f.write("THis is second line\n")

# %%
with open("./dummy.txt" , 'a+') as f:
    f.write("and it is third line\n")
    f.write("THis is fourth line\n")

# %%
with open("./dummy.txt" , 'a+') as f:
    f.seek(0)
    content = f.read()
    print(content)
# Out:
# Hello it is first line
# THis is second line
# and it is third line
# THis is fourth line
