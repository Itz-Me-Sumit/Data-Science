# %%
import matplotlib.pyplot as plt
from data import Data
obj = Data()
df = obj.get_data()
clean_data = obj.get_clean_data()

# %%
clean_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue    Month
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30  2010-12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00  2010-12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12

# %%
monthly_revenue = clean_data.groupby('Month')["Revenue"].sum().sort_index()
monthly_revenue.head()
# Out:
# Month
# 2010-12    572713.890
# 2011-01    569445.040
# 2011-02    447137.350
# 2011-03    595500.760
# 2011-04    469200.361
# Name: Revenue, dtype: float64

# %%
monthly_revenue.index
# Out:
# Index(['2010-12', '2011-01', '2011-02', '2011-03', '2011-04', '2011-05',
#        '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11',
#        '2011-12'],
#       dtype='str', name='Month')

# %%
monthly_revenue.values
# Out:
# array([ 572713.89 ,  569445.04 ,  447137.35 ,  595500.76 ,  469200.361,
#         678594.56 ,  661213.69 ,  600091.011,  645343.9  ,  952838.382,
#        1039318.79 , 1161817.38 ,  518192.79 ])
