# %%
import pandas as pd

data = {
    'a':10,
    'b':20,
    'c':30,
    'd':40,
    'e':50
}


s1 = pd.Series(data)
print(s1)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
