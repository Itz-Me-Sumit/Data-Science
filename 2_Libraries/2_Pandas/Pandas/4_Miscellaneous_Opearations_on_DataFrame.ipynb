# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

data = {
    "model_name":[
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost",
        "LightGBM",
        "KNN",
        "Naive Bayes",
        "SVM",
        "CNN",
        "LSTM"
    ],
    "execution_time": [0.5, 0.8, 2.3, 3.1, 2.8, 1.2, 0.6, 1.9, 4.5, 5.0],
    "model_size": [2.3, 5.6, 45.2, 60.1, 55.8, 8.4, 1.2, 12.3, 120.5, 150.7],
    "accuracy": [0.82, 0.78, 0.89, 0.91, 0.90, 0.76, 0.74, 0.88, 0.93, 0.92],
    "f1_score": [0.80, 0.75, 0.87, 0.90, 0.89, 0.74, 0.72, 0.86, 0.92, 0.91],
    "precision": [0.81, 0.76, 0.88, 0.91, 0.90, 0.75, 0.73, 0.87, 0.93, 0.92],
    "recall": [0.79, 0.74, 0.86, 0.89, 0.88, 0.73, 0.71, 0.85, 0.91, 0.90],
}

df = pd.DataFrame(data)
df
# Out:
#             model_name  execution_time  model_size  accuracy  f1_score  \
# 0  Logistic Regression             0.5         2.3      0.82      0.80
# 1        Decision Tree             0.8         5.6      0.78      0.75
# 2        Random Forest             2.3        45.2      0.89      0.87
# 3              XGBoost             3.1        60.1      0.91      0.90
# 4             LightGBM             2.8        55.8      0.90      0.89
# 5                  KNN             1.2         8.4      0.76      0.74
# 6          Naive Bayes             0.6         1.2      0.74      0.72
# 7                  SVM             1.9        12.3      0.88      0.86
# 8                  CNN             4.5       120.5      0.93      0.92
# 9                 LSTM             5.0       150.7      0.92      0.91
#
#    precision  recall
# 0       0.81    0.79
# 1       0.76    0.74
# 2       0.88    0.86
# 3       0.91    0.89
# 4       0.90    0.88
# 5       0.75    0.73
# 6       0.73    0.71
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   model_name      10 non-null     str
#  1   execution_time  10 non-null     float64
#  2   model_size      10 non-null     float64
#  3   accuracy        10 non-null     float64
#  4   f1_score        10 non-null     float64
#  5   precision       10 non-null     float64
#  6   recall          10 non-null     float64
# dtypes: float64(6), str(1)
# memory usage: 692.0 bytes

# %%
def testfunc(series):
    arr = "_".join(series.split())
    arr=arr.lower()
    return arr

# %%
s = df["model_name"].apply(testfunc)
s
# Out:
# 0    logistic_regression
# 1          decision_tree
# 2          random_forest
# 3                xgboost
# 4               lightgbm
# 5                    knn
# 6            naive_bayes
# 7                    svm
# 8                    cnn
# 9                   lstm
# Name: model_name, dtype: str

# %% [markdown]
# ### DateTime in pandas

# %%
pd.Timestamp("2025-08-18 14:30:15")
# Out:
# Timestamp('2025-08-18 14:30:15')

# %%
pd.Timestamp("2025-08-15")
# Out:
# Timestamp('2025-08-15 00:00:00')

# %%
pd.Timestamp("15-08-2025")
# Out:
# Timestamp('2025-08-15 00:00:00')

# %%
pd.Timestamp(year=2025 , month=8 , day=18 , hour=14 , minute=30 , second=15)
# Out:
# Timestamp('2025-08-18 14:30:15')

# %%
pd.Timestamp(year=2025 , month=8 , day=18)
# Out:
# Timestamp('2025-08-18 00:00:00')

# %%
ts1 = pd.Timestamp("2025-08-15")
pd.date_range(ts1 , periods=5)
# Out:
# DatetimeIndex(['2025-08-15', '2025-08-16', '2025-08-17', '2025-08-18',
#                '2025-08-19'],
#               dtype='datetime64[us]', freq='D')

# %% [markdown]
# #### Adding Time using Timedelta

# %%
pd.Timestamp(2025,9,22)
# Out:
# Timestamp('2025-09-22 00:00:00')

# %%
pd.Timestamp(2025,9,22) + pd.Timedelta(days=6 , hours=7)
# Out:
# Timestamp('2025-09-28 07:00:00')
