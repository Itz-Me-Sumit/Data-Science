# %%
import psycopg2
import json

# %%
def read_db_config(config_file="db_config.json"):
    try:
        with open(config_file , "r") as f:
            config=json.load(f)
            print(f"Database Config Loaded from file : {config_file}")
        return config
    except Exception as e:
        print(f"Error Occured while reading file : {config_file} , Error: {e}")

# %%
def connect_to_postgres(db_name , user , password , host , port):
    connection = None
    try:
        connection=psycopg2.connect(
            database=db_name,
            user=user,
            password=password,
            host=host,
            port=port
        )
        print(f"Connection To postgreSQL DB({db_name}) successful")
        return connection

    except Exception as e:
        print(f"Error Occured While Creating Connection to DB {db_name}")
        return connection

# %%
db_config = read_db_config()
print(db_config)

DB_NAME = db_config.get("db_name")
USER = db_config.get("user")
PASSWORD = db_config.get("password")
HOST = db_config.get("host")
PORT = db_config.get("port")

if db_config:
    conn=connect_to_postgres(DB_NAME,USER,PASSWORD,HOST,PORT)
    print(conn)
# Out:
# Database Config Loaded from file : db_config.json
# {'db_name': 'chinook', 'user': 'postgres', 'password': '@Sumit123', 'host': 'localhost', 'port': '5432'}
# Connection To postgreSQL DB(chinook) successful
# <connection object at 0x0000025294FFF340; dsn: 'user=postgres password=xxx dbname=chinook host=localhost port=5432', closed: 0>

# %%
def execute_query(conn,query,params=None):
    try:
        cursor = conn.cursor()
        cursor.execute(query , params)

        if query.upper().startswith(("INSERT","UPDATE","DELETE")):
            cursor.commit()
            return cursor.rowcount()
        else:
            return cursor.fetchall()
    except Exception as e:
        if conn:
            conn.rollback()
        print(f"Error Occured While Running Query , Error : {e}")
        return None
    finally:
        if cursor:
            cursor.close()

# %%
query = "SELECT * FROM Artist LIMIT 20;"

# %%
if conn:
    result = execute_query(conn , query)
    if result is None:
        print("Result set is empty")
    else:
        for id ,(artist_id , artist_name) in enumerate(result):
            print(f"{id}:-> Artist Id: {artist_id} | Artist Name: {artist_name}")
# Out:
# 0:-> Artist Id: 1 | Artist Name: AC/DC
# 1:-> Artist Id: 2 | Artist Name: Accept
# 2:-> Artist Id: 3 | Artist Name: Aerosmith
# 3:-> Artist Id: 4 | Artist Name: Alanis Morissette
# 4:-> Artist Id: 5 | Artist Name: Alice In Chains
# 5:-> Artist Id: 6 | Artist Name: AntÃ´nio Carlos Jobim
# 6:-> Artist Id: 7 | Artist Name: Apocalyptica
# 7:-> Artist Id: 8 | Artist Name: Audioslave
# 8:-> Artist Id: 9 | Artist Name: BackBeat
# 9:-> Artist Id: 10 | Artist Name: Billy Cobham
# 10:-> Artist Id: 11 | Artist Name: Black Label Society
# 11:-> Artist Id: 12 | Artist Name: Black Sabbath
# 12:-> Artist Id: 13 | Artist Name: Body Count
# 13:-> Artist Id: 14 | Artist Name: Bruce Dickinson
# 14:-> Artist Id: 15 | Artist Name: Buddy Guy
# 15:-> Artist Id: 16 | Artist Name: Caetano Veloso
# 16:-> Artist Id: 17 | Artist Name: Chico Buarque
# 17:-> Artist Id: 18 | Artist Name: Chico Science & NaÃ§Ã£o Zumbi
# 18:-> Artist Id: 19 | Artist Name: Cidade Negra
# 19:-> Artist Id: 20 | Artist Name: ClÃ¡udio Zoli
