# %%
import numpy as np

# %%
class ConfidenceInterval:

    def __init__(self , sample):
        self.sample = np.array(sample , dtype=float)
    
    def ConfidenceInterval(self , confidence):
        self.confidence = confidence
