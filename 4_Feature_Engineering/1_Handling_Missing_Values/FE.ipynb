# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open ("test.csv" , "r") as f:
    df = pd.read_csv(f)

# %%
df.shape
# Out:
# (1459, 80)

# %%
rows = df.shape[0]
columns = df.shape[1]
print(f"Rows: {rows} , Columns: {columns}")
# Out:
# Rows: 1459 , Columns: 80

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
missing_values = df.isnull().sum()
missing_values[missing_values>0].sort_values(ascending=False)
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# MasVnrType       894
# FireplaceQu      730
# LotFrontage      227
# GarageQual        78
# GarageCond        78
# GarageYrBlt       78
# GarageFinish      78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrArea        15
# MSZoning           4
# Functional         2
# BsmtFullBath       2
# Utilities          2
# BsmtHalfBath       2
# Exterior1st        1
# Exterior2nd        1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# KitchenQual        1
# GarageArea         1
# GarageCars         1
# SaleType           1
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
# Shows How Much data missing column-wise
plt.figure(figsize=(12,8))
msno.bar(df)
plt.show()

# %%
plt.figure(figsize=(12,8))
msno.heatmap(df)
plt.show()

"""
value = 1 -> both columns tends to bemissing together
value = 0 -> no relation
value = -ve -> if one is missing , second is probably present 
"""
# Out:
# '\nvalue = 1 -> both columns tends to bemissing together\nvalue = 0 -> no relation\nvalue = -ve -> if one is missing , second is probably present \n'

# %% [markdown]
# ### Deletion of NaN

# %%
data_with_not_NaN = df.dropna()  # if any row contains even a single NaN , that row will get deleted
print("Original Shape: " , df.shape)
print("Without NaN: " , data_with_not_NaN.shape)
# Out:
# Original Shape:  (1459, 80)
# Without NaN:  (0, 80)

# %% [markdown]
# ### Simple Imputation
# - insted of deleting , we'll fill missing values with estimates

# %%
# (a) Mean Imputation : for Numerical Data
df_mean=df.copy()

# df_mean['LotFrontage'].fillna( {df_mean['LotFrontage'].mean()} , inplace=True )

df_mean.fillna({'LotFrontage': df_mean['LotFrontage'].mean()}, inplace=True)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...
